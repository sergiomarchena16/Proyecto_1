# %% [markdown]
# # Proyecto 1 - Deteccion de Ataques
# Sergio Marchena - 16387

# %% [markdown]
# ## Parte 1
# ### Fase 1: Analisis Exploratorio

# %%
# libraries
import pandas as pd

# %%
# load the datasets(1 and 2)
df_part1 = pd.read_csv('dataset-part1.csv', encoding='utf-8')
df_part2 = pd.read_csv('dataset-part2.csv', encoding='utf-8')

# %%
# quick check of the datasets
df_part2.head()
df_part1.head()
# Out:
#    BIFLOW_DIRECTION  DIRECTION DST_TO_SRC_SECOND_BYTES  FIREWALL_EVENT  \
# 0                 1          0                      40               0
# 1                 1          0                       ,               0
# 2                 1          0                     104               0
# 3                 1          0                       ,               0
# 4                 1          0                      40               0
#
#    FIRST_SWITCHED  FLOW_ACTIVE_TIMEOUT  FLOW_DURATION_MICROSECONDS  \
# 0      1616660040                  120                         339
# 1      1616660040                  120                           0
# 2      1616660040                  120                       44725
# 3      1616660040                  120                           0
# 4      1616660040                  120                        1114
#
#    FLOW_DURATION_MILLISECONDS  FLOW_END_MILLISECONDS  FLOW_END_SEC  ...  \
# ...

# %%
# merge the dataframes in order to work only with one
frames = [df_part1, df_part2]
df = pd.concat(frames, ignore_index=True)

# %%
# check the target value count
df['LABEL'].value_counts()
# Out:
# Normal flow                       6570058
# SYN Scan - aggressive             2496814
# Denial of Service R-U-Dead-Yet    2276947
# Denial of Service Slowloris        864054
# Name: LABEL, dtype: int64

# %%
totalObservations = 6570058 + 2496814 + 2276947 + 864054
print('Total Observations: ', str(totalObservations))
# Out:
# Total Observations:  12207873
